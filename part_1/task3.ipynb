# %%
from IPython.display import Image

Image("images/task_3.jpg")

# %%
Image("images/answer_3_1.jpg")

# %%
Image("images/answer_3_2.jpg")

# %%
Image("images/answer_3_3.jpg")

# %%
Image("images/answer_3_4.jpg")

# %%
Image("images/answer_3_5.jpg")
