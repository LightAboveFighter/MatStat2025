# %%
from IPython.display import Image

Image("images/task_1.jpg")

# %%
Image("images/answer_1_1.jpg")

# %%
Image("images/answer_1_2.jpg")

# %%
Image("images/answer_1_3.jpg")

# %%
Image("images/answer_1_4.jpg")

# %%
Image("images/answer_1_5.jpg")
